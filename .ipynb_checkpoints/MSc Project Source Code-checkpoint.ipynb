# %% [markdown]
# # Project: Investigating Takeaway Density and Obesity in London
# ## Data Science and Analytics MSc Project
#
# **Student:** Zisan Ahmed
#
# ## Notebook Overview
#
# performs the initial data loading, cleaning, and exploratory analysis.
# - Load the raw datasets
# - Understand its structure and identify missing values
# - Filter for London only
# - Filter for takeaway-type businesses
# - Perform basic visualisations

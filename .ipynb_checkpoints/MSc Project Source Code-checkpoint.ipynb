# %% [markdown]
# # Project: Investigating Takeaway Density and Obesity in London
# ## Data Science and Analytics MSc Project
#
# **Student:** Zisan Ahmed

# %% [markdown]
# - Loading the two main datasets: FHRS (food businesses) and IMD 2019 (deprivation scores)
# - Inspect their structure, missing values, and basic statistics
# - Create initial visualisations to understand the data

# %%
# Importing all necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Display settings
pd.set_option('display.max_columns', 50)
pd.set_option('display.max_rows', 30)

print("Libraries imported successfully.")
# Out:
# Libraries imported successfully.

# %% [markdown]
# ## 1. Load Food Hygiene Rating Scheme (FHRS) Data
#
# Loading the FHRS CSV file that contains records of food businesses in the UK.
#
# This is my main dataset. It contains information about takeaways, their locations, business types, and hygiene ratings.
#
# Using `pd.read_csv()`. I will check the first few rows to understand the columns.

# %%
# Loading the FHRS dataset
fhrs_df = pd.read_csv('/Users/zisan/My Docs/Projects and Research(Git)/Advance-MSc-Project_Takeaway-Density-Deprivation-Obesity-in-London/ApprovedEstablishments01-06-2026.csv')  # update path

print("="*60)
print("FHRS DATASET - BASIC INFO")
print("="*60)

print(f"Shape: {fhrs_df.shape[0]} rows, {fhrs_df.shape[1]} columns")
print(f"\nMemory usage: {fhrs_df.memory_usage(deep=True).sum() / 1024**2:.2f} MB")

print("\nFirst 20 rows:")
fhrs_df.head(20)
# Out:
# ...
# FHRS DATASET - BASIC INFO
# ...
# Shape: 5315 rows, 71 columns
#
# Memory usage: 13.55 MB
#
# First 20 rows:
#    AppNo                                        TradingName  \
# 0   1000                           Ahmed Brothers Halal Ltd
# 1   1003                                    Kinda Foods Ltd
# 2   1004                                    Newby Foods Ltd
# 3   1006                               Aubrey Allen Limited
# 4   1007                           Frank Bird (Poultry) Ltd
# 5   1012                        CSP (Food Services) Limited
# 6   1014                                   Trendy Foods Ltd
# 7   1018                                Bodiam Meat Company
# 8   1019                     Fairfax Meadow Europe Limited
# 9   1024                                           Thorners
# 10  1025          Gilders Transport Ltd (T/A Martins Meats)
# 11  1026  Simon D Hall Anne M Hall & John D Hall (T/A Ha...
# 12  1028                       Swandean Fresh Meats Limited
# ...

# %% [markdown]
# ## 2. Understand FHRS Columns and Data Types
#
# Listing all column names and their data types.
#
# I need to identify which columns contain:
# - Business location (postcode, local authority)
# - Business type (takeaway, restaurant, etc.)
# - Hygiene rating
# - Any geographical identifiers
#
# Using `df.columns` and `df.dtypes`.

# %%
# Listing all columns with their data types
print("FHRS Columns:\n")
for i, col in enumerate(fhrs_df.columns):
    dtype = fhrs_df[col].dtype
    print(f"{i+1:3d}. {col:30s} ({dtype})")

# Count of each data type
print("\n" + "="*60)
print("Data type summary:")
print(fhrs_df.dtypes.value_counts())
# Out:
# FHRS Columns:
#
#   1. AppNo                          (object)
#   2. TradingName                    (object)
#   3. Address1                       (object)
#   4. Address2                       (object)
#   5. Address3                       (object)
#   6. Town                           (object)
#   7. Postcode                       (object)
#   8. Country                        (object)
#   9. All_Activities                 (object)
#  10. Part_A__Section_0__General_activity_establishment (object)
#  11. Part_A__Section_I__Meat_of_domestic_ungulates (object)
#  12. Part_A__Section_II__Meat_from_poultry_and_lagomorphs (object)
#  13. Part_A__Section_III__Meat_of_farmed_game (object)
#  14. Part_A__Section_IV__Wild_game_meat (object)
#  15. Part_A__Section_V__Minced_meat__meat_preparations_and_mechanically_separated_meat (object)
#  16. Part_A__Section_VI__Meat_products (object)
#  17. Part_A__Section_VII__Live_bivalve_molluscs (object)
# ...

# %% [markdown]
# ## 3. Checking for Missing Values
#
# Counting null values in each column.
#
# **Why?** FHRS data is known to be messy. Missing postcodes or business types will need to be handled. This helps me plan my cleaning strategy.

# %%
# Calculate missing values
missing_count = fhrs_df.isnull().sum()
missing_pct = (missing_count / len(fhrs_df)) * 100

missing_df = pd.DataFrame({
    'Missing Count': missing_count,
    'Percentage': missing_pct
}).sort_values(by='Percentage', ascending=False)

# Show only columns with missing values
missing_with_data = missing_df[missing_df['Missing Count'] > 0]
print(f"Columns with missing values: {len(missing_with_data)}")
print(missing_with_data)

# Critical columns check
print("\n" + "="*60)
print("CRITICAL COLUMNS CHECK:")
critical_cols = ['PostCode', 'BusinessType', 'RatingValue', 'LocalAuthorityName']
for col in critical_cols:
    if col in fhrs_df.columns:
        miss = fhrs_df[col].isnull().sum()
        print(f"{col:25s}: {miss:6d} missing ({miss/len(fhrs_df)*100:.2f}%)")
    else:
        print(f"{col:25s}: Column not found")
# Out:
# Columns with missing values: 65
#                           Missing Count  Percentage
# Lagomorphs                         5315  100.000000
# Tannery                            5315  100.000000
# reefer_vessel                      5315  100.000000
# Ratite                             5314   99.981185
# Solipeds                           5312   99.943556
# ...                                 ...         ...
# AddressWithheld                     829   15.597366
# Address1                            110    2.069614
# Postcode                            107    2.013170
# Part_A__All_sections_                 6    0.112888
# GeographicLocalAuthority              4    0.075259
#
# [65 rows x 2 columns]
#
# ...
# CRITICAL COLUMNS CHECK:
# PostCode                 : Column not found
# BusinessType             : Column not found
# RatingValue              : Column not found
# LocalAuthorityName       : Column not found

# %% [markdown]
# ## 4. Filtering for Takeaway-Type Businesses
#
# Keeping only rows where BusinessType contains keywords like 'Takeaway', 'Fast Food', 'Kebab', etc.
#
# My Project focuses specifically on takeaways (fast-food outlets). The Pineda 2024 paper found that fast-food proximity is associated with higher obesity.
#
# Using `str.contains()` with case-insensitive matching and a list of keywords.

# %%
# Keywords for takeaway businesses
takeaway_keywords = [
    'Takeaway', 'Fast Food', 'Sandwich', 'Kebab', 
    'Burger', 'Pizza', 'Fried Chicken', 'Mobile'
]

# Create a mask (True for takeaway rows)
if 'BusinessType' in fhrs_df.columns:
    mask = fhrs_df['BusinessType'].str.contains(
        '|'.join(takeaway_keywords), 
        case=False, 
        na=False
    )
    takeaways_df = fhrs_df[mask]
    
    print(f"Original rows: {len(fhrs_df):,}")
    print(f"Takeaway rows: {len(takeaways_df):,}")
    print(f"Percentage takeaways: {len(takeaways_df)/len(fhrs_df)*100:.2f}%")
    
    # Show top business types among takeaways
    print("\nTop 10 Business Types (Takeaways only):")
    print(takeaways_df['BusinessType'].value_counts().head(10))
else:
    print("Column 'BusinessType' not found. Check column names.")
    takeaways_df = fhrs_df  # fallback
# Out:
# Column 'BusinessType' not found. Check column names.

# %% [markdown]
# ## 5. Visualising Hygiene Ratings of Takeaways
#
# Creating a bar chart showing the distribution of food hygiene ratings (0-5) for takeaway businesses.
#
# **Why?** This is an initial exploration. It helps me understand the data quality and may reveal interesting patterns (e.g., most takeaways have good ratings).
#
# Using `matplotlib` to create a bar chart.

# %%
# Check if RatingValue column exists
if 'RatingValue' in takeaways_df.columns:
    # Count ratings (excluding missing)
    rating_counts = takeaways_df['RatingValue'].value_counts().sort_index()
    
    print("Hygiene Rating Distribution:\n")
    for rating, count in rating_counts.items():
        print(f"Rating {rating}: {count:6d} takeaways")
    
    # Create bar chart
    plt.figure(figsize=(10, 6))
    bars = plt.bar(rating_counts.index.astype(str), rating_counts.values, 
                   color='skyblue', edgecolor='black')
    
    plt.title('Food Hygiene Ratings of Takeaways in London', fontsize=14)
    plt.xlabel('Hygiene Rating (0-5, 5 = very good)', fontsize=12)
    plt.ylabel('Number of Takeaways', fontsize=12)
    
    # Add value labels on bars
    for bar in bars:
        height = bar.get_height()
        plt.text(bar.get_x() + bar.get_width()/2., height + 5,
                 f'{int(height)}', ha='center', va='bottom')
    
    plt.tight_layout()
    plt.savefig('takeaway_ratings.png', dpi=150)
    plt.show()
    
    print("\nChart saved as 'takeaway_ratings.png'")
else:
    print("Column 'RatingValue' not found.")
# Out:
# Column 'RatingValue' not found.
